# %%
import sympy as sp


x, y = sp.symbols('x y')

f = sp.exp(x)*sp.sin(y)+y**3
df_dx = sp.diff(f, x)
df_dy = sp.diff(f, y)

print (df_dx)
print (df_dy)
# Out:
# exp(x)*sin(y)
# 3*y**2 + exp(x)*cos(y)

# %%
import numpy as np
from mpl_toolkits import mplot3d #for 3D plots
import matplotlib.pyplot as plt #usual matplotlib


def gradient_descent(x0, y0, fun_1, grad_f_1, alpha, num_iterations):
   
    """
Parameters:
x0, y0: Initial point for the descent.
f: a function of two variables
grad_f: the gradient of f
alpha: Learning rate.
num_iterations: Number of iterations to perform.
Returns:
(x, y): The coordinates of the final point after gradient descent.
"""
    x, y = x0,y0
# Initialize x and y with the initial point

    for i in range(num_iterations):
# obtain the gradient of f at (x, y)
        grad_x, grad_y = grad_f_1(x,y)
        # Update x and y by taking a step in the opposite direction of gradient
        x = x - (alpha)*grad_x
        y = y - (alpha)*grad_y

    return x,y
#the function
def fun_1(x,y):
    
    return y*x**2 + x*y**2
#partial derivative for x and y
def grad_f_1(x,y):
    grad_x = 2 * x
    grad_y = 2 * y
    
    return grad_x, grad_y
#parameters
x0= 1
y0 = -1
alpha =0.1
num_iterations=10

x_f, y_f = gradient_descent(x0, y0, fun_1, grad_f_1, alpha, num_iterations)

print("Point after gradient descent:", (x_f, y_f))
# Out:
# Point after gradient descent: (0.10737418240000003, -0.10737418240000003)

# %%
import sympy as sp


x, y = sp.symbols('x y')

f = sp.ln(x**+y**2)
df_dx2 = sp.diff(f, x, 2)
df_dy2 = sp.diff(f, y, 2)
df_dxy = sp.diff(f, x, y)

print (df_dx2)
print (df_dy2)
print (df_dxy)
# Out:
# -y**2/x**2
# 2*log(x)
# 2*y/x

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

x, y = sp.symbols('x y')
j = x**3 - 3*x*y + y**3

j_func = sp.lambdify((x, y), j, 'numpy')

x_vals = np.linspace(-3, 3, 400)
y_vals = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(x_vals, y_vals)
Z = j_func(X, Y)

plt.contourf(X, Y, Z, levels=50, cmap='viridis')
plt.colorbar()
plt.title('Contour plot of $j(x, y) = x^3 - 3xy + y^3$')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.show()

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

x, y = sp.symbols('x y')
j = x*3 - 10*x + y**9

j_func = sp.lambdify((x, y), j, 'numpy')

x_vals = np.linspace(-3, 3, 400)
y_vals = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(x_vals, y_vals)
Z = j_func(X, Y)

plt.contourf(X, Y, Z, levels=50, cmap='viridis')
plt.colorbar()
plt.title('Contour plot of $j(x, y) = 3x - 10x + y^9')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.show()
